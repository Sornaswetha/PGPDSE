# %% [markdown]
# # IN CLASS LAB EXERCISE - 02

# %% [markdown]
# (Kaggle Automobile Dataset)
#
#  We will be using the [automobiles Dataset](https://www.kaggle.com/nisargpatel/automobiles/data) from Kaggle.
#
# **INCLASS LAB EXERCISE** answer below question. Load pandas as pd and upload the Automobile.csv file as auto

# %% [markdown]
# --------

# %%
import pandas as pd
df= pd.read_csv('Automobile.csv')

# %% [markdown]
# **Q.no(1). Check the head of the DataFrame.**

# %%
df.head()
# Out:
#    symboling  normalized_losses         make fuel_type aspiration  \
# 0          3                168  alfa-romero       gas        std
# 1          3                168  alfa-romero       gas        std
# 2          1                168  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   number_of_doors   body_style drive_wheels engine_location  wheel_base  ...  \
# 0             two  convertible          rwd           front        88.6  ...
# 1             two  convertible          rwd           front        88.6  ...
# 2             two    hatchback          rwd           front        94.5  ...
# 3            four        sedan          fwd           front        99.8  ...
# 4            four        sedan          4wd           front        99.4  ...
#
#    engine_size  fuel_system  bore  stroke compression_ratio horsepower  \
# 0          130         mpfi  3.47    2.68               9.0        111
# 1          130         mpfi  3.47    2.68               9.0        111
# 2          152         mpfi  2.68    3.47               9.0        154
# 3          109         mpfi  3.19    3.40              10.0        102
# 4          136         mpfi  3.19    3.40               8.0        115
#
#    peak_rpm city_mpg  highway_mpg  price
# 0      5000       21           27  13495
# 1      5000       21           27  16500
# 2      5000       19           26  16500
# 3      5500       24           30  13950
# 4      5500       18           22  17450
#
# [5 rows x 26 columns]

# %% [markdown]
# ------------------

# %% [markdown]
# **Q.no(2). How many rows and columns are there.**

# %%
df.shape
# Out:
# (201, 26)

# %% [markdown]
# ---------------------

# %% [markdown]
# **Q.no(3). What is the average Price of all cars in the dataset.**

# %%
df.mean(axis = 0) ['price']
# Out:
# 13207.129353233831

# %% [markdown]
# -------------------------------

# %% [markdown]
# **Q.no(4). Which is the cheapest make and costliest make of car in the lot.**

# %%
print ("Costliest Make : ", df[df ['price'] == df.max(axis = 0)['price']]['make'] ," Price = ",df.max(axis = 0)['price'])
print ("Cheapest  Make : ",df[df ['price'] == df.min(axis = 0)['price']]['make'] ," Price = ",df.min(axis = 0)['price'])
# Out:
# Costliest Make :  71    mercedes-benz
# Name: make, dtype: object  Price =  45400
# Cheapest  Make :  134    subaru
# Name: make, dtype: object  Price =  5118

# %% [markdown]
# --------------------

# %% [markdown]
# **Q.no(5). How many cars have horsepower greater than 100.**

# %%
df[df['horsepower']>100].count()['horsepower']
# Out:
# 90

# %% [markdown]
# ----------------

# %% [markdown]
# **Q.no(6). How many hatchback cars are in the dataset .**

# %%
df[df['body_style'] =='hatchback'].count()['body_style']
# Out:
# 68

# %% [markdown]
# -------------------

# %% [markdown]
# **Q.no(7). What are the 3 most commonly found cars in the dataset?**

# %%
df["make"].value_counts()
# Out:
# toyota           32
# nissan           18
# mazda            17
# mitsubishi       13
# honda            13
# volkswagen       12
# subaru           12
# peugot           11
# volvo            11
# dodge             9
# mercedes-benz     8
# bmw               8
# plymouth          7
# saab              6
# audi              6
# porsche           4
# alfa-romero       3
# jaguar            3
# chevrolet         3
# isuzu             2
# renault           2
# mercury           1
# Name: make, dtype: int64

# %%
df["make"].value_counts()[0:3]
# Out:
# toyota    32
# nissan    18
# mazda     17
# Name: make, dtype: int64

# %% [markdown]
# -----

# %% [markdown]
# **Q.no(8). Someone purchased a car for 7099, what is the make of the car?**

# %%
df[df['price']==7099]['make']
# Out:
# 87    nissan
# Name: make, dtype: object

# %% [markdown]
# -------------

# %% [markdown]
# **Q.no(9). Which cars are priced greater than 40000.**

# %%
df[df['price'] >4000]['make']
# Out:
# 0      alfa-romero
# 1      alfa-romero
# 2      alfa-romero
# 3             audi
# 4             audi
# 5             audi
# 6             audi
# 7             audi
# 8             audi
# 9              bmw
# 10             bmw
# 11             bmw
# 12             bmw
# 13             bmw
# 14             bmw
# 15             bmw
# 16             bmw
# 17       chevrolet
# 18       chevrolet
# 19       chevrolet
# 20           dodge
# 21           dodge
# 22           dodge
# 23           dodge
# 24           dodge
# 25           dodge
# 26           dodge
# 27           dodge
# 28           dodge
# 29           honda
#           ...
# 171         toyota
# 172         toyota
# 173         toyota
# 174         toyota
# 175         toyota
# 176         toyota
# 177         toyota
# 178     volkswagen
# 179     volkswagen
# 180     volkswagen
# 181     volkswagen
# 182     volkswagen
# 183     volkswagen
# 184     volkswagen
# 185     volkswagen
# 186     volkswagen
# 187     volkswagen
# 188     volkswagen
# 189     volkswagen
# 190          volvo
# 191          volvo
# 192          volvo
# 193          volvo
# 194          volvo
# 195          volvo
# 196          volvo
# 197          volvo
# 198          volvo
# 199          volvo
# 200          volvo
# Name: make, Length: 201, dtype: object

# %% [markdown]
# ---

# %% [markdown]
# **Q.no(10). Which are the cars that are both a sedan and priced less than 7000?**

# %%
df[(df['body_style'] =='hatchback' )& (df['price'] < 7000) ]
# Out:
#      symboling  normalized_losses        make fuel_type aspiration  \
# 17           2                121   chevrolet       gas        std
# 18           1                 98   chevrolet       gas        std
# 20           1                118       dodge       gas        std
# 21           1                118       dodge       gas        std
# 23           1                148       dodge       gas        std
# 29           2                137       honda       gas        std
# 30           2                137       honda       gas        std
# 31           1                101       honda       gas        std
# 32           1                101       honda       gas        std
# 47           1                104       mazda       gas        std
# 48           1                104       mazda       gas        std
# 49           1                104       mazda       gas        std
# 73           2                161  mitsubishi       gas        std
# 74           2                161  mitsubishi       gas        std
# 75           2                161  mitsubishi       gas        std
# 115          1                119    plymouth       gas        std
# 117          1                154    plymouth       gas        std
# 134          2                 83      subaru       gas        std
# 146          1                 87      toyota       gas        std
# 147          1                 87      toyota       gas        std
# 148          1                 74      toyota       gas        std
#
#     number_of_doors body_style drive_wheels engine_location  wheel_base  ...  \
# 17              two  hatchback          fwd           front        88.4  ...
# 18              two  hatchback          fwd           front        94.5  ...
# 20              two  hatchback          fwd           front        93.7  ...
# 21              two  hatchback          fwd           front        93.7  ...
# 23             four  hatchback          fwd           front        93.7  ...
# 29              two  hatchback          fwd           front        86.6  ...
# 30              two  hatchback          fwd           front        86.6  ...
# 31              two  hatchback          fwd           front        93.7  ...
# 32              two  hatchback          fwd           front        93.7  ...
# 47              two  hatchback          fwd           front        93.1  ...
# 48              two  hatchback          fwd           front        93.1  ...
# 49              two  hatchback          fwd           front        93.1  ...
# 73              two  hatchback          fwd           front        93.7  ...
# 74              two  hatchback          fwd           front        93.7  ...
# 75              two  hatchback          fwd           front        93.7  ...
# 115             two  hatchback          fwd           front        93.7  ...
# 117            four  hatchback          fwd           front        93.7  ...
# 134             two  hatchback          fwd           front        93.7  ...
# 146             two  hatchback          fwd           front        95.7  ...
# 147             two  hatchback          fwd           front        95.7  ...
# 148            four  hatchback          fwd           front        95.7  ...
#
#      fuel_system  bore  stroke  compression_ratio horsepower peak_rpm  \
# 17          2bbl  2.91    3.03               9.50         48     5100
# 18          2bbl  3.03    3.11               9.60         70     5400
# 20          2bbl  2.97    3.23               9.41         68     5500
# 21          2bbl  2.97    3.23               9.40         68     5500
# 23          2bbl  2.97    3.23               9.40         68     5500
# 29          1bbl  2.91    3.41               9.60         58     4800
# 30          1bbl  2.91    3.41               9.20         76     6000
# 31          1bbl  2.91    3.07              10.10         60     5500
# 32          1bbl  2.91    3.41               9.20         76     6000
# 47          2bbl  3.03    3.15               9.00         68     5000
# 48          2bbl  3.03    3.15               9.00         68     5000
# 49          2bbl  3.03    3.15               9.00         68     5000
# 73          2bbl  2.97    3.23               9.40         68     5500
# 74          2bbl  2.97    3.23               9.40         68     5500
# 75          2bbl  2.97    3.23               9.40         68     5500
# 115         2bbl  2.97    3.23               9.40         68     5500
# 117         2bbl  2.97    3.23               9.40         68     5500
# 134         2bbl  3.62    2.36               9.00         69     4900
# 146         2bbl  3.05    3.03               9.00         62     4800
# 147         2bbl  3.05    3.03               9.00         62     4800
# 148         2bbl  3.05    3.03               9.00         62     4800
#
#      city_mpg highway_mpg  price  Rank
# 17         47          53   5151   2.0
# 18         38          43   6295  12.0
# 20         37          41   5572   8.0
# 21         31          38   6377  14.0
# 23         31          38   6229  11.0
# 29         49          54   6479  15.0
# 30         31          38   6855  26.0
# 31         38          42   5399   6.0
# 32         30          34   6529  17.0
# 47         30          31   5195   3.0
# 48         31          38   6095   9.0
# 49         31          38   6795  24.0
# 73         37          41   5389   5.0
# 74         31          38   6189  10.0
# 75         31          38   6669  20.0
# 115        37          41   5572   8.0
# 117        31          38   6229  11.0
# 134        31          36   5118   1.0
# 146        35          39   5348   4.0
# 147        31          38   6338  13.0
# 148        31          38   6488  16.0
#
# [21 rows x 27 columns]

# %% [markdown]
# ---------------

# %% [markdown]
# **Q.no(11) Show the prices of cars in ascending order.**

# %%
df.sort_values(by ="price")
# Out:
#      symboling  normalized_losses           make fuel_type aspiration  \
# 134          2                 83         subaru       gas        std
# 17           2                121      chevrolet       gas        std
# 47           1                104          mazda       gas        std
# 146          1                 87         toyota       gas        std
# 73           2                161     mitsubishi       gas        std
# 31           1                101          honda       gas        std
# 86           1                128         nissan       gas        std
# 115          1                119       plymouth       gas        std
# 20           1                118          dodge       gas        std
# 48           1                104          mazda       gas        std
# 74           2                161     mitsubishi       gas        std
# 23           1                148          dodge       gas        std
# 117          1                154       plymouth       gas        std
# 18           1                 98      chevrolet       gas        std
# 147          1                 87         toyota       gas        std
# 21           1                118          dodge       gas        std
# 29           2                137          honda       gas        std
# 148          1                 74         toyota       gas        std
# 32           1                101          honda       gas        std
# 19           0                 81      chevrolet       gas        std
# 88           1                128         nissan       gas        std
# 75           2                161     mitsubishi       gas        std
# 118          1                154       plymouth       gas        std
# 24           1                148          dodge       gas        std
# 50           1                113          mazda       gas        std
# 42           0                110          isuzu       gas        std
# 49           1                104          mazda       gas        std
# 89           1                122         nissan       gas        std
# 30           2                137          honda       gas        std
# 149          0                 77         toyota       gas        std
# ..         ...                ...            ...       ...        ...
# 133          2                104           saab       gas      turbo
# 7            1                168           audi       gas        std
# 195         -1                 74          volvo       gas      turbo
# 197         -1                 95          volvo       gas      turbo
# 102          3                194         nissan       gas      turbo
# 11           0                188            bmw       gas        std
# 12           0                188            bmw       gas        std
# 198         -1                 95          volvo       gas        std
# 122          3                186        porsche       gas        std
# 199         -1                 95          volvo    diesel      turbo
# 200         -1                 95          volvo       gas      turbo
# 8            1                158           audi       gas      turbo
# 13           1                149            bmw       gas        std
# 64          -1                 93  mercedes-benz    diesel      turbo
# 66           0                 93  mercedes-benz    diesel      turbo
# 65          -1                 93  mercedes-benz    diesel      turbo
# 14           0                149            bmw       gas        std
# 67          -1                 93  mercedes-benz    diesel      turbo
# 44           0                145         jaguar       gas        std
# 123          3                128        porsche       gas        std
# 124          3                128        porsche       gas        std
# 68          -1                122  mercedes-benz       gas        std
# 69           3                142  mercedes-benz       gas        std
# 45           0                115         jaguar       gas        std
# 46           0                115         jaguar       gas        std
# 16           0                149            bmw       gas        std
# 125          3                128        porsche       gas        std
# 70           0                140  mercedes-benz       gas        std
# 15           0                149            bmw       gas        std
# 71           1                140  mercedes-benz       gas        std
#
#     number_of_doors   body_style drive_wheels engine_location  wheel_base  \
# 134             two    hatchback          fwd           front        93.7
# 17              two    hatchback          fwd           front        88.4
# 47              two    hatchback          fwd           front        93.1
# 146             two    hatchback          fwd           front        95.7
# 73              two    hatchback          fwd           front        93.7
# 31              two    hatchback          fwd           front        93.7
# 86              two        sedan          fwd           front        94.5
# 115             two    hatchback          fwd           front        93.7
# 20              two    hatchback          fwd           front        93.7
# 48              two    hatchback          fwd           front        93.1
# 74              two    hatchback          fwd           front        93.7
# 23             four    hatchback          fwd           front        93.7
# 117            four    hatchback          fwd           front        93.7
# 18              two    hatchback          fwd           front        94.5
# 147             two    hatchback          fwd           front        95.7
# 21              two    hatchback          fwd           front        93.7
# 29              two    hatchback          fwd           front        86.6
# 148            four    hatchback          fwd           front        95.7
# 32              two    hatchback          fwd           front        93.7
# 19             four        sedan          fwd           front        94.5
# 88              two        sedan          fwd           front        94.5
# 75              two    hatchback          fwd           front        93.7
# 118            four        sedan          fwd           front        93.7
# 24             four        sedan          fwd           front        93.7
# 50             four        sedan          fwd           front        93.1
# 42             four        sedan          rwd           front        94.3
# 49              two    hatchback          fwd           front        93.1
# 89             four        sedan          fwd           front        94.5
# 30              two    hatchback          fwd           front        86.6
# 149            four        wagon          fwd           front        95.7
# ..              ...          ...          ...             ...         ...
# 133            four        sedan          fwd           front        99.1
# 7              four        wagon          fwd           front       105.8
# 195            four        wagon          rwd           front       104.3
# 197            four        sedan          rwd           front       109.1
# 102             two    hatchback          rwd           front        91.3
# 11              two        sedan          rwd           front       101.2
# 12             four        sedan          rwd           front       101.2
# 198            four        sedan          rwd           front       109.1
# 122             two    hatchback          rwd           front        94.5
# 199            four        sedan          rwd           front       109.1
# 200            four        sedan          rwd           front       109.1
# 8              four        sedan          fwd           front       105.8
# 13             four        sedan          rwd           front       103.5
# 64             four        sedan          rwd           front       110.0
# 66              two      hardtop          rwd           front       106.7
# 65             four        wagon          rwd           front       110.0
# 14             four        sedan          rwd           front       103.5
# 67             four        sedan          rwd           front       115.6
# 44             four        sedan          rwd           front       113.0
# 123             two      hardtop          rwd            rear        89.5
# 124             two      hardtop          rwd            rear        89.5
# 68             four        sedan          rwd           front       115.6
# 69              two  convertible          rwd           front        96.6
# 45             four        sedan          rwd           front       113.0
# 46              two        sedan          rwd           front       102.0
# 16             four        sedan          rwd           front       110.0
# 125             two  convertible          rwd            rear        89.5
# 70             four        sedan          rwd           front       120.9
# 15              two        sedan          rwd           front       103.5
# 71              two      hardtop          rwd           front       112.0
#
#      ...  fuel_system  bore  stroke  compression_ratio horsepower peak_rpm  \
# 134  ...         2bbl  3.62    2.36               9.00         69     4900
# 17   ...         2bbl  2.91    3.03               9.50         48     5100
# 47   ...         2bbl  3.03    3.15               9.00         68     5000
# 146  ...         2bbl  3.05    3.03               9.00         62     4800
# 73   ...         2bbl  2.97    3.23               9.40         68     5500
# 31   ...         1bbl  2.91    3.07              10.10         60     5500
# 86   ...         2bbl  3.15    3.29               9.40         69     5200
# 115  ...         2bbl  2.97    3.23               9.40         68     5500
# 20   ...         2bbl  2.97    3.23               9.41         68     5500
# 48   ...         2bbl  3.03    3.15               9.00         68     5000
# 74   ...         2bbl  2.97    3.23               9.40         68     5500
# 23   ...         2bbl  2.97    3.23               9.40         68     5500
# 117  ...         2bbl  2.97    3.23               9.40         68     5500
# 18   ...         2bbl  3.03    3.11               9.60         70     5400
# 147  ...         2bbl  3.05    3.03               9.00         62     4800
# 21   ...         2bbl  2.97    3.23               9.40         68     5500
# 29   ...         1bbl  2.91    3.41               9.60         58     4800
# 148  ...         2bbl  3.05    3.03               9.00         62     4800
# 32   ...         1bbl  2.91    3.41               9.20         76     6000
# 19   ...         2bbl  3.03    3.11               9.60         70     5400
# 88   ...         2bbl  3.15    3.29               9.40         69     5200
# 75   ...         2bbl  2.97    3.23               9.40         68     5500
# 118  ...         2bbl  2.97    3.23               9.40         68     5500
# 24   ...         2bbl  2.97    3.23               9.40         68     5500
# 50   ...         2bbl  3.03    3.15               9.00         68     5000
# 42   ...         2bbl  3.31    3.23               8.50         78     4800
# 49   ...         2bbl  3.03    3.15               9.00         68     5000
# 89   ...         2bbl  3.15    3.29               9.40         69     5200
# 30   ...         1bbl  2.91    3.41               9.20         76     6000
# 149  ...         2bbl  3.05    3.03               9.00         62     4800
# ..   ...          ...   ...     ...                ...        ...      ...
# 133  ...         mpfi  3.54    3.07               9.00        160     5500
# 7    ...         mpfi  3.19    3.40               8.50        110     5500
# 195  ...         mpfi  3.62    3.15               7.50        162     5100
# 197  ...         mpfi  3.78    3.15               8.70        160     5300
# 102  ...         mpfi  3.43    3.27               7.80        200     5200
# 11   ...         mpfi  3.31    3.19               9.00        121     4250
# 12   ...         mpfi  3.31    3.19               9.00        121     4250
# 198  ...         mpfi  3.58    2.87               8.80        134     5500
# 122  ...         mpfi  3.94    3.11               9.50        143     5500
# 199  ...          idi  3.01    3.40              23.00        106     4800
# 200  ...         mpfi  3.78    3.15               9.50        114     5400
# 8    ...         mpfi  3.13    3.40               8.30        140     5500
# 13   ...         mpfi  3.31    3.19               9.00        121     4250
# 64   ...          idi  3.58    3.64              21.50        123     4350
# 66   ...          idi  3.58    3.64              21.50        123     4350
# 65   ...          idi  3.58    3.64              21.50        123     4350
# 14   ...         mpfi  3.62    3.39               8.00        182     5400
# 67   ...          idi  3.58    3.64              21.50        123     4350
# 44   ...         mpfi  3.63    4.17               8.10        176     4750
# 123  ...         mpfi  3.74    2.90               9.50        207     5900
# 124  ...         mpfi  3.74    2.90               9.50        207     5900
# 68   ...         mpfi  3.46    3.10               8.30        155     4750
# 69   ...         mpfi  3.46    3.10               8.30        155     4750
# 45   ...         mpfi  3.63    4.17               8.10        176     4750
# 46   ...         mpfi  3.54    2.76              11.50        262     5000
# 16   ...         mpfi  3.62    3.39               8.00        182     5400
# 125  ...         mpfi  3.74    2.90               9.50        207     5900
# 70   ...         mpfi  3.80    3.35               8.00        184     4500
# 15   ...         mpfi  3.62    3.39               8.00        182     5400
# 71   ...         mpfi  3.80    3.35               8.00        184     4500
#
#      city_mpg highway_mpg  price   Rank
# 134        31          36   5118    1.0
# 17         47          53   5151    2.0
# 47         30          31   5195    3.0
# 146        35          39   5348    4.0
# 73         37          41   5389    5.0
# 31         38          42   5399    6.0
# 86         31          37   5499    7.0
# 115        37          41   5572    8.0
# 20         37          41   5572    8.0
# 48         31          38   6095    9.0
# 74         31          38   6189   10.0
# 23         31          38   6229   11.0
# 117        31          38   6229   11.0
# 18         38          43   6295   12.0
# 147        31          38   6338   13.0
# 21         31          38   6377   14.0
# 29         49          54   6479   15.0
# 148        31          38   6488   16.0
# 32         30          34   6529   17.0
# 19         38          43   6575   18.0
# 88         31          37   6649   19.0
# 75         31          38   6669   20.0
# 118        31          38   6692   21.0
# 24         31          38   6692   21.0
# 50         31          38   6695   22.0
# 42         24          29   6785   23.0
# 49         31          38   6795   24.0
# 89         31          37   6849   25.0
# 30         31          38   6855   26.0
# 149        31          37   6918   27.0
# ..        ...         ...    ...    ...
# 133        19          26  18620  157.0
# 7          19          25  18920  158.0
# 195        17          22  18950  159.0
# 197        19          25  19045  160.0
# 102        17          23  19699  161.0
# 11         21          28  20970  162.0
# 12         21          28  21105  163.0
# 198        18          23  21485  164.0
# 122        19          27  22018  165.0
# 199        26          27  22470  166.0
# 200        19          25  22625  167.0
# 8          17          20  23875  168.0
# 13         20          25  24565  169.0
# 64         22          25  25552  170.0
# 66         22          25  28176  171.0
# 65         22          25  28248  172.0
# 14         16          22  30760  173.0
# 67         22          25  31600  174.0
# 44         15          19  32250  175.0
# 123        17          25  32528  176.0
# 124        17          25  34028  177.0
# 68         16          18  34184  178.0
# 69         16          18  35056  179.0
# 45         15          19  35550  180.0
# 46         13          17  36000  181.0
# 16         15          20  36880  182.0
# 125        17          25  37028  183.0
# 70         14          16  40960  184.0
# 15         16          22  41315  185.0
# 71         14          16  45400  186.0
#
# [201 rows x 27 columns]

# %% [markdown]
# --------

# %% [markdown]
# **Q.no(12).Show the prices of the cars in descending order.**

# %%
df.sort_values(by ="price" ,ascending= False )
# Out:
#      symboling  normalized_losses           make fuel_type aspiration  \
# 71           1                140  mercedes-benz       gas        std
# 15           0                149            bmw       gas        std
# 70           0                140  mercedes-benz       gas        std
# 125          3                128        porsche       gas        std
# 16           0                149            bmw       gas        std
# 46           0                115         jaguar       gas        std
# 45           0                115         jaguar       gas        std
# 69           3                142  mercedes-benz       gas        std
# 68          -1                122  mercedes-benz       gas        std
# 124          3                128        porsche       gas        std
# 123          3                128        porsche       gas        std
# 44           0                145         jaguar       gas        std
# 67          -1                 93  mercedes-benz    diesel      turbo
# 14           0                149            bmw       gas        std
# 65          -1                 93  mercedes-benz    diesel      turbo
# 66           0                 93  mercedes-benz    diesel      turbo
# 64          -1                 93  mercedes-benz    diesel      turbo
# 13           1                149            bmw       gas        std
# 8            1                158           audi       gas      turbo
# 200         -1                 95          volvo       gas      turbo
# 199         -1                 95          volvo    diesel      turbo
# 122          3                186        porsche       gas        std
# 198         -1                 95          volvo       gas        std
# 12           0                188            bmw       gas        std
# 11           0                188            bmw       gas        std
# 102          3                194         nissan       gas      turbo
# 197         -1                 95          volvo       gas      turbo
# 195         -1                 74          volvo       gas      turbo
# 7            1                168           audi       gas        std
# 133          2                104           saab       gas      turbo
# ..         ...                ...            ...       ...        ...
# 149          0                 77         toyota       gas        std
# 30           2                137          honda       gas        std
# 89           1                122         nissan       gas        std
# 49           1                104          mazda       gas        std
# 42           0                110          isuzu       gas        std
# 50           1                113          mazda       gas        std
# 24           1                148          dodge       gas        std
# 118          1                154       plymouth       gas        std
# 75           2                161     mitsubishi       gas        std
# 88           1                128         nissan       gas        std
# 19           0                 81      chevrolet       gas        std
# 32           1                101          honda       gas        std
# 148          1                 74         toyota       gas        std
# 29           2                137          honda       gas        std
# 21           1                118          dodge       gas        std
# 147          1                 87         toyota       gas        std
# 18           1                 98      chevrolet       gas        std
# 117          1                154       plymouth       gas        std
# 23           1                148          dodge       gas        std
# 74           2                161     mitsubishi       gas        std
# 48           1                104          mazda       gas        std
# 115          1                119       plymouth       gas        std
# 20           1                118          dodge       gas        std
# 86           1                128         nissan       gas        std
# 31           1                101          honda       gas        std
# 73           2                161     mitsubishi       gas        std
# 146          1                 87         toyota       gas        std
# 47           1                104          mazda       gas        std
# 17           2                121      chevrolet       gas        std
# 134          2                 83         subaru       gas        std
#
#     number_of_doors   body_style drive_wheels engine_location  wheel_base  \
# 71              two      hardtop          rwd           front       112.0
# 15              two        sedan          rwd           front       103.5
# 70             four        sedan          rwd           front       120.9
# 125             two  convertible          rwd            rear        89.5
# 16             four        sedan          rwd           front       110.0
# 46              two        sedan          rwd           front       102.0
# 45             four        sedan          rwd           front       113.0
# 69              two  convertible          rwd           front        96.6
# 68             four        sedan          rwd           front       115.6
# 124             two      hardtop          rwd            rear        89.5
# 123             two      hardtop          rwd            rear        89.5
# 44             four        sedan          rwd           front       113.0
# 67             four        sedan          rwd           front       115.6
# 14             four        sedan          rwd           front       103.5
# 65             four        wagon          rwd           front       110.0
# 66              two      hardtop          rwd           front       106.7
# 64             four        sedan          rwd           front       110.0
# 13             four        sedan          rwd           front       103.5
# 8              four        sedan          fwd           front       105.8
# 200            four        sedan          rwd           front       109.1
# 199            four        sedan          rwd           front       109.1
# 122             two    hatchback          rwd           front        94.5
# 198            four        sedan          rwd           front       109.1
# 12             four        sedan          rwd           front       101.2
# 11              two        sedan          rwd           front       101.2
# 102             two    hatchback          rwd           front        91.3
# 197            four        sedan          rwd           front       109.1
# 195            four        wagon          rwd           front       104.3
# 7              four        wagon          fwd           front       105.8
# 133            four        sedan          fwd           front        99.1
# ..              ...          ...          ...             ...         ...
# 149            four        wagon          fwd           front        95.7
# 30              two    hatchback          fwd           front        86.6
# 89             four        sedan          fwd           front        94.5
# 49              two    hatchback          fwd           front        93.1
# 42             four        sedan          rwd           front        94.3
# 50             four        sedan          fwd           front        93.1
# 24             four        sedan          fwd           front        93.7
# 118            four        sedan          fwd           front        93.7
# 75              two    hatchback          fwd           front        93.7
# 88              two        sedan          fwd           front        94.5
# 19             four        sedan          fwd           front        94.5
# 32              two    hatchback          fwd           front        93.7
# 148            four    hatchback          fwd           front        95.7
# 29              two    hatchback          fwd           front        86.6
# 21              two    hatchback          fwd           front        93.7
# 147             two    hatchback          fwd           front        95.7
# 18              two    hatchback          fwd           front        94.5
# 117            four    hatchback          fwd           front        93.7
# 23             four    hatchback          fwd           front        93.7
# 74              two    hatchback          fwd           front        93.7
# 48              two    hatchback          fwd           front        93.1
# 115             two    hatchback          fwd           front        93.7
# 20              two    hatchback          fwd           front        93.7
# 86              two        sedan          fwd           front        94.5
# 31              two    hatchback          fwd           front        93.7
# 73              two    hatchback          fwd           front        93.7
# 146             two    hatchback          fwd           front        95.7
# 47              two    hatchback          fwd           front        93.1
# 17              two    hatchback          fwd           front        88.4
# 134             two    hatchback          fwd           front        93.7
#
#      ...  engine_size  fuel_system  bore  stroke compression_ratio horsepower  \
# 71   ...          304         mpfi  3.80    3.35              8.00        184
# 15   ...          209         mpfi  3.62    3.39              8.00        182
# 70   ...          308         mpfi  3.80    3.35              8.00        184
# 125  ...          194         mpfi  3.74    2.90              9.50        207
# 16   ...          209         mpfi  3.62    3.39              8.00        182
# 46   ...          326         mpfi  3.54    2.76             11.50        262
# 45   ...          258         mpfi  3.63    4.17              8.10        176
# 69   ...          234         mpfi  3.46    3.10              8.30        155
# 68   ...          234         mpfi  3.46    3.10              8.30        155
# 124  ...          194         mpfi  3.74    2.90              9.50        207
# 123  ...          194         mpfi  3.74    2.90              9.50        207
# 44   ...          258         mpfi  3.63    4.17              8.10        176
# 67   ...          183          idi  3.58    3.64             21.50        123
# 14   ...          209         mpfi  3.62    3.39              8.00        182
# 65   ...          183          idi  3.58    3.64             21.50        123
# 66   ...          183          idi  3.58    3.64             21.50        123
# 64   ...          183          idi  3.58    3.64             21.50        123
# 13   ...          164         mpfi  3.31    3.19              9.00        121
# 8    ...          131         mpfi  3.13    3.40              8.30        140
# 200  ...          141         mpfi  3.78    3.15              9.50        114
# 199  ...          145          idi  3.01    3.40             23.00        106
# 122  ...          151         mpfi  3.94    3.11              9.50        143
# 198  ...          173         mpfi  3.58    2.87              8.80        134
# 12   ...          164         mpfi  3.31    3.19              9.00        121
# 11   ...          164         mpfi  3.31    3.19              9.00        121
# 102  ...          181         mpfi  3.43    3.27              7.80        200
# 197  ...          141         mpfi  3.78    3.15              8.70        160
# 195  ...          130         mpfi  3.62    3.15              7.50        162
# 7    ...          136         mpfi  3.19    3.40              8.50        110
# 133  ...          121         mpfi  3.54    3.07              9.00        160
# ..   ...          ...          ...   ...     ...               ...        ...
# 149  ...           92         2bbl  3.05    3.03              9.00         62
# 30   ...           92         1bbl  2.91    3.41              9.20         76
# 89   ...           97         2bbl  3.15    3.29              9.40         69
# 49   ...           91         2bbl  3.03    3.15              9.00         68
# 42   ...          111         2bbl  3.31    3.23              8.50         78
# 50   ...           91         2bbl  3.03    3.15              9.00         68
# 24   ...           90         2bbl  2.97    3.23              9.40         68
# 118  ...           90         2bbl  2.97    3.23              9.40         68
# 75   ...           92         2bbl  2.97    3.23              9.40         68
# 88   ...           97         2bbl  3.15    3.29              9.40         69
# 19   ...           90         2bbl  3.03    3.11              9.60         70
# 32   ...           92         1bbl  2.91    3.41              9.20         76
# 148  ...           92         2bbl  3.05    3.03              9.00         62
# 29   ...           92         1bbl  2.91    3.41              9.60         58
# 21   ...           90         2bbl  2.97    3.23              9.40         68
# 147  ...           92         2bbl  3.05    3.03              9.00         62
# 18   ...           90         2bbl  3.03    3.11              9.60         70
# 117  ...           90         2bbl  2.97    3.23              9.40         68
# 23   ...           90         2bbl  2.97    3.23              9.40         68
# 74   ...           92         2bbl  2.97    3.23              9.40         68
# 48   ...           91         2bbl  3.03    3.15              9.00         68
# 115  ...           90         2bbl  2.97    3.23              9.40         68
# 20   ...           90         2bbl  2.97    3.23              9.41         68
# 86   ...           97         2bbl  3.15    3.29              9.40         69
# 31   ...           79         1bbl  2.91    3.07             10.10         60
# 73   ...           92         2bbl  2.97    3.23              9.40         68
# 146  ...           92         2bbl  3.05    3.03              9.00         62
# 47   ...           91         2bbl  3.03    3.15              9.00         68
# 17   ...           61         2bbl  2.91    3.03              9.50         48
# 134  ...           97         2bbl  3.62    2.36              9.00         69
#
#      peak_rpm city_mpg  highway_mpg  price
# 71       4500       14           16  45400
# 15       5400       16           22  41315
# 70       4500       14           16  40960
# 125      5900       17           25  37028
# 16       5400       15           20  36880
# 46       5000       13           17  36000
# 45       4750       15           19  35550
# 69       4750       16           18  35056
# 68       4750       16           18  34184
# 124      5900       17           25  34028
# 123      5900       17           25  32528
# 44       4750       15           19  32250
# 67       4350       22           25  31600
# 14       5400       16           22  30760
# 65       4350       22           25  28248
# 66       4350       22           25  28176
# 64       4350       22           25  25552
# 13       4250       20           25  24565
# 8        5500       17           20  23875
# 200      5400       19           25  22625
# 199      4800       26           27  22470
# 122      5500       19           27  22018
# 198      5500       18           23  21485
# 12       4250       21           28  21105
# 11       4250       21           28  20970
# 102      5200       17           23  19699
# 197      5300       19           25  19045
# 195      5100       17           22  18950
# 7        5500       19           25  18920
# 133      5500       19           26  18620
# ..        ...      ...          ...    ...
# 149      4800       31           37   6918
# 30       6000       31           38   6855
# 89       5200       31           37   6849
# 49       5000       31           38   6795
# 42       4800       24           29   6785
# 50       5000       31           38   6695
# 24       5500       31           38   6692
# 118      5500       31           38   6692
# 75       5500       31           38   6669
# 88       5200       31           37   6649
# 19       5400       38           43   6575
# 32       6000       30           34   6529
# 148      4800       31           38   6488
# 29       4800       49           54   6479
# 21       5500       31           38   6377
# 147      4800       31           38   6338
# 18       5400       38           43   6295
# 117      5500       31           38   6229
# 23       5500       31           38   6229
# 74       5500       31           38   6189
# 48       5000       31           38   6095
# 115      5500       37           41   5572
# 20       5500       37           41   5572
# 86       5200       31           37   5499
# 31       5500       38           42   5399
# 73       5500       37           41   5389
# 146      4800       35           39   5348
# 47       5000       30           31   5195
# 17       5100       47           53   5151
# 134      4900       31           36   5118
#
# [201 rows x 26 columns]

# %% [markdown]
# ----------------

# %% [markdown]
# **Q.no(12).What is the rank order of the cars as per there horsepower.**

# %%
df['Rank'] = df["horsepower"].rank()

# %% [markdown]
# ---------------------

# %% [markdown]
# **Q.no(13).What is the rank order of the cars as per there minimum prices.**

# %%
df['Rank'] = df["price"].rank(ascending = True)

# %% [markdown]
# ------

# %% [markdown]
# **Q.no(14).What is the rank order of the cars as per there maximum prices.**

# %%
df['Rank'] = df["price"].rank(ascending = False)

# %% [markdown]
# -------------

# %% [markdown]
# **Q.no(15).What is the dense rank order of the cars as per there horsepower.**

# %%
df['Rank'] = df["price"].rank(ascending = True , method ="dense" )

# %% [markdown]
# --------------

# %% [markdown]
# **Q.no(16). Write a code to display the  `make` and `price` of `5,6,10` rows.**

# %%
df.loc[[5,6,10], ["make" ,"price"]]
# Out:
#     make  price
# 5   audi  15250
# 6   audi  17710
# 10   bmw  16925

# %% [markdown]
# ------

# %% [markdown]
# **Q.no(17). Write a code to display the  `first five columns` and  `5 to 10 rows` using as per `index position`.**

# %%
df.iloc[ 5:11, 0:5]
# Out:
#     symboling  normalized_losses  make fuel_type aspiration
# 5           2                161  audi       gas        std
# 6           1                158  audi       gas        std
# 7           1                168  audi       gas        std
# 8           1                158  audi       gas      turbo
# 9           2                192   bmw       gas        std
# 10          0                192   bmw       gas        std

# %% [markdown]
# ------------------------------------

# %% [markdown]
# # ----------------------------------HAPPY LEARNING----------------------------------------

# %% [markdown]
# -------
