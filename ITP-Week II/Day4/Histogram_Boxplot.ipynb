# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
df = pd.read_csv('house_train.csv')
df.shape
# Out:
# (1460, 81)

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
SaleCondition = df.SaleCondition.value_counts()
print( SaleCondition ,type(SaleCondition) ,SaleCondition.values,SaleCondition.index ,sep ="\n")
SaleCondition.plot(kind="bar")
plt.show()
# Out:
# Normal     1198
# Partial     125
# Abnorml     101
# Family       20
# Alloca       12
# AdjLand       4
# Name: SaleCondition, dtype: int64
# <class 'pandas.core.series.Series'>
# [1198  125  101   20   12    4]
# Index(['Normal', 'Partial', 'Abnorml', 'Family', 'Alloca', 'AdjLand'], dtype='object')

# %% [markdown]
# ## Usind DataFrames.plot

# %%
df.SaleCondition.value_counts().plot(kind="bar")
plt.show()

# %% [markdown]
# ## Using matplotlib.pyplot.bar

# %%
plt.bar ( df.SaleCondition.value_counts().index , df.SaleCondition.value_counts().values )
plt.show()

# %% [markdown]
# # Histogram
#
# - Frequency vs Range
# - A histogram is a graphical display of data using bars of different heights.
# - In a histogram, each bar groups numbers into ranges. Taller bars show that more data falls in that range.
# - A histogram displays the shape and spread of continuous sample data.
#
# - Only one axis is required

# %% [markdown]
# ## Using df.plot

# %%
df.plot(kind = "hist" , y = "SalePrice")
plt.show()

# %%
df.plot(kind = "hist" , y = "SalePrice" , bins =25 , edgecolor = "white" , legend = False )
plt.show()

# %% [markdown]
# ##### 1. Histogram of LotFrontage

# %%
df.plot(kind = "hist" , y = "LotFrontage"  , edgecolor = "white")
plt.show()

# %% [markdown]
# ## using plt.hist

# %% [markdown]
# https://matplotlib.org/api/_as_gen/matplotlib.pyplot.hist.html
#
# This function returns an array

# %%
plt.hist( df["LotFrontage"] )
plt.show()

# %%
plt.hist( df["LotFrontage"] )
plt.show()

# %% [markdown]
# # Box Plot
#
# - panda df plot
# - df. boxplot()
# - plt.boxplot()

# %%
df.plot ( kind = 'box', y = 'SalePrice')
plt.show()

# %%
plt.boxplot( df["SalePrice"].values ,notch =True )
plt.show()

# %% [markdown]
# https://matplotlib.org/api/_as_gen/matplotlib.pyplot.boxplot.html

# %%
plt.boxplot( df["SalePrice"].values ,vert=False)
plt.show()

# %% [markdown]
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.boxplot.html

# %%
df.boxplot('SalePrice','SaleCondition')
plt.show()

# %% [markdown]
# # ScatterPlot

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df.plot(kind="scatter", x ="YrSold", y= "SalePrice")

# %%
plt.scatter ( x =df["YrSold"], y= df["SalePrice"])
plt.show()

# %% [markdown]
# https://matplotlib.org/api/_as_gen/matplotlib.pyplot.scatter.html

# %% [markdown]
# # KDE plot -Kernel density estimation

# %%
df.plot ( kind ="kde" , y= ["SalePrice"] , title = "Kernel density estimation", )
plt.show()

# %% [markdown]
# #### Area Plot`

# %%
df['YearBuilt'].value_counts().plot(kind="area")
plt.show()

# %%
df['YearBuilt'].value_counts().sort_index().plot(kind="area")
plt.show()

# %%
df['YearBuilt'].value_counts()
df['YearBuilt'].value_counts().sort_index()
a= df['YearBuilt'].value_counts().sort_index()
a.plot(kind="pie")
