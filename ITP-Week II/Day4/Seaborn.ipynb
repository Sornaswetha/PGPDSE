# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
df = pd.read_csv('house_train.csv')

# %% [markdown]
# ### Boxplot()
#
# https://seaborn.pydata.org/generated/seaborn.boxplot.html

# %%
sns.boxplot( data= df["SalePrice"] )
plt.show()

# %%
sns.boxplot( df["SalePrice"] )
plt.show()

# %% [markdown]
# **data:**  DataFrame, array, or list of arrays, optional
#
# Dataset for plotting. If x and y are absent, this is interpreted as wide-form. Otherwise it is expected to be long-form.

# %% [markdown]
# ### displot()
# This function combines the matplotlib hist function (with automatic calculation of a good default bin size) with the seaborn kdeplot() and rugplot() functions
#
# https://seaborn.pydata.org/generated/seaborn.distplot.html

# %%
sns.distplot( df["SalePrice"] )
plt.show()

# %% [markdown]
# ### Correlation

# %%
df.corr()
# Out:
#                      Id  MSSubClass  LotFrontage   LotArea  OverallQual  \
# Id             1.000000    0.011156    -0.010601 -0.033226    -0.028365
# MSSubClass     0.011156    1.000000    -0.386347 -0.139781     0.032628
# LotFrontage   -0.010601   -0.386347     1.000000  0.426095     0.251646
# LotArea       -0.033226   -0.139781     0.426095  1.000000     0.105806
# OverallQual   -0.028365    0.032628     0.251646  0.105806     1.000000
# OverallCond    0.012609   -0.059316    -0.059213 -0.005636    -0.091932
# YearBuilt     -0.012713    0.027850     0.123349  0.014228     0.572323
# YearRemodAdd  -0.021998    0.040581     0.088866  0.013788     0.550684
# MasVnrArea    -0.050298    0.022936     0.193458  0.104160     0.411876
# BsmtFinSF1    -0.005024   -0.069836     0.233633  0.214103     0.239666
# BsmtFinSF2    -0.005968   -0.065649     0.049900  0.111170    -0.059119
# BsmtUnfSF     -0.007940   -0.140759     0.132644 -0.002618     0.308159
# ...

# %%
a = df.corr()

# %%
sns.heatmap(a)
plt.show()

# %% [markdown]
# ### Pair Plot()
#
# - Takes only numerical data

# %%
sns.pairplot(df [['SalePrice', 'OverallQual', 'GrLivArea', 'GarageCars', 'TotalBsmtSF', 'FullBath', 'YearBuilt']] , size =1.5)
plt.show()

# %%
sns.regplot(data=df, x="YearBuilt", y= "SalePrice")
plt.show()

# %% [markdown]
# ### joint plot
#
# - Scatter of x and y
# - histogram of x and y
# - where more distribution is there (hist) , scattering density will be more  .We can say that as positive correlation

# %%
sns.jointplot(x=df['LotFrontage'],y=df['LotArea'],color='red');

# %%
sns.jointplot(x=df['LotFrontage'],y=df['LotArea'],color='red' , kind = "kde" ) ;
