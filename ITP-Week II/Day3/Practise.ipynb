# %%
import pandas as pd
df = pd.DataFrame( { "Name" : ["Ram" ,"Siva","Krishna","Abdul","John","Jack"] , "Salary": [ 200000, 100000,50000,75000,250000,125000] , 
        "Designation" : [ "Manager", "Manager","Developer"," Jr_Data_Scientist", "Data_Scientist", "Data_Scientist"]  , "Exp" : [12,7,5,5,15,8]} )
df
# Out:
#       Name  Salary         Designation  Exp
# 0      Ram  200000             Manager   12
# 1     Siva  100000             Manager    7
# 2  Krishna   50000           Developer    5
# 3    Abdul   75000   Jr_Data_Scientist    5
# 4     John  250000      Data_Scientist   15
# 5     Jack  125000      Data_Scientist    8

# %% [markdown]
# ##### 1. Print Name and Designtion

# %%
df[["Name", "Designation"]]
# Out:
#       Name         Designation
# 0      Ram             Manager
# 1     Siva             Manager
# 2  Krishna           Developer
# 3    Abdul   Jr_Data_Scientist
# 4     John      Data_Scientist
# 5     Jack      Data_Scientist

# %% [markdown]
# ##### 2. Using iloc() extract 3rd index value

# %%
df.iloc[3]
# Out:
# Name                        Abdul
# Salary                      75000
# Designation     Jr_Data_Scientist
# Exp                             5
# Name: 3, dtype: object

# %% [markdown]
# ##### 3. extract 1:4

# %%
df.iloc[1:5]
# Out:
#       Name  Salary         Designation  Exp
# 1     Siva  100000             Manager    7
# 2  Krishna   50000           Developer    5
# 3    Abdul   75000   Jr_Data_Scientist    5
# 4     John  250000      Data_Scientist   15

# %% [markdown]
# ##### 4. extracct value 4,5 ussing loc()

# %%
df.loc[ [4,5] ]
# Out:
#    Name  Salary     Designation  Exp
# 4  John  250000  Data_Scientist   15
# 5  Jack  125000  Data_Scientist    8

# %% [markdown]
# ##### 5. extrct 1 to 3, column salary to exp using iloc() and loc()

# %%
df.iloc [ 1:4 , 1:]
# Out:
#    Salary         Designation  Exp
# 1  100000             Manager    7
# 2   50000           Developer    5
# 3   75000   Jr_Data_Scientist    5

# %%
df.loc() [[1,2,3] , ["Salary" , "Designation" ,"Exp"]]
# Out:
#    Salary         Designation  Exp
# 1  100000             Manager    7
# 2   50000           Developer    5
# 3   75000   Jr_Data_Scientist    5

# %% [markdown]
# ##### 6. extract salary > 100000

# %%
df [ df ["Salary"] > 100000  ]
# Out:
#    Name  Salary     Designation  Exp
# 0   Ram  200000         Manager   12
# 4  John  250000  Data_Scientist   15
# 5  Jack  125000  Data_Scientist    8

# %%
df [ df ["Salary"] > 100000  ]["Name"]
# Out:
# 0     Ram
# 4    John
# 5    Jack
# Name: Name, dtype: object

# %%
df [ df ["Salary"] > 100000  ][ ["Name" ,"Exp"] ]
# Out:
#    Name  Exp
# 0   Ram   12
# 4  John   15
# 5  Jack    8

# %% [markdown]
# ##### 7. designation is DS and exp >7

# %%
df [ (df ["Designation"] == "Data_Scientist" ) & (df["Exp"] > 7 ) ]
# Out:
#    Name  Salary     Designation  Exp
# 4  John  250000  Data_Scientist   15
# 5  Jack  125000  Data_Scientist    8

# %% [markdown]
# ##### 8.Add a column "Company" with values as"GL"

# %%
df["Company"] = "GL"
df
# Out:
#       Name  Salary         Designation  Exp Company
# 0      Ram  200000             Manager   12      GL
# 1     Siva  100000             Manager    7      GL
# 2  Krishna   50000           Developer    5      GL
# 3    Abdul   75000   Jr_Data_Scientist    5      GL
# 4     John  250000      Data_Scientist   15      GL
# 5     Jack  125000      Data_Scientist    8      GL

# %% [markdown]
# ##### 9. "Location" = "Chennai" ,"Banglore", "Banglore","Hyderabad", "Cheannai", "Hyderabad"

# %%
df["Location"] = ["Chennai" ,"Banglore", "Banglore","Hyderabad", "Cheannai", "Hyderabad"]
df
# Out:
#       Name  Salary         Designation  Exp Company   Location
# 0      Ram  200000             Manager   12      GL    Chennai
# 1     Siva  100000             Manager    7      GL   Banglore
# 2  Krishna   50000           Developer    5      GL   Banglore
# 3    Abdul   75000   Jr_Data_Scientist    5      GL  Hyderabad
# 4     John  250000      Data_Scientist   15      GL   Cheannai
# 5     Jack  125000      Data_Scientist    8      GL  Hyderabad

# %% [markdown]
# ##### 10 . New Row as  "Rajesh", 80000, "Data_Scientist" , 10, "GL", "Chennai"

# %%
df.loc[ len(df)] = ["Rajesh", 80000, "Data_Scientist" , 10, "GL", "Chennai"]

# %%
df
# Out:
#       Name  Salary         Designation  Exp Company   Location
# 0      Ram  200000             Manager   12      GL    Chennai
# 1     Siva  100000             Manager    7      GL   Banglore
# 2  Krishna   50000           Developer    5      GL   Banglore
# 3    Abdul   75000   Jr_Data_Scientist    5      GL  Hyderabad
# 4     John  250000      Data_Scientist   15      GL   Cheannai
# 5     Jack  125000      Data_Scientist    8      GL  Hyderabad
# 6   Rajesh   80000      Data_Scientist   10      GL    Chennai

# %% [markdown]
# ##### 11 . Remove "Company" column

# %%
df.drop(["Company"], axis =1 , inplace = True )

# %%
df
# Out:
#       Name  Salary         Designation  Exp   Location
# 0      Ram  200000             Manager   12    Chennai
# 1     Siva  100000             Manager    7   Banglore
# 2  Krishna   50000           Developer    5   Banglore
# 3    Abdul   75000   Jr_Data_Scientist    5  Hyderabad
# 4     John  250000      Data_Scientist   15   Cheannai
# 5     Jack  125000      Data_Scientist    8  Hyderabad
# 6   Rajesh   80000      Data_Scientist   10    Chennai

# %% [markdown]
# ##### 12. Remove the entry of "Krishna"

# %%
df.drop([2], axis =0 , inplace = True )

# %%
df
# Out:
#      Name  Salary         Designation  Exp   Location
# 0     Ram  200000             Manager   12    Chennai
# 1    Siva  100000             Manager    7   Banglore
# 3   Abdul   75000   Jr_Data_Scientist    5  Hyderabad
# 4    John  250000      Data_Scientist   15   Cheannai
# 5    Jack  125000      Data_Scientist    8  Hyderabad
# 6  Rajesh   80000      Data_Scientist   10    Chennai

# %% [markdown]
# ##### 13. Rename Row and Column

# %%
df.rename({ "Exp": "No_of_Years"} , axis = 1 , inplace =True )
df.rename({ 4: 'd'} , axis = 0 , inplace =True )
df
# Out:
#      Name  Salary         Designation  No_of_Years   Location
# 0     Ram  200000             Manager           12    Chennai
# 1    Siva  100000             Manager            7   Banglore
# 3   Abdul   75000   Jr_Data_Scientist            5  Hyderabad
# d    John  250000      Data_Scientist           15   Cheannai
# 5    Jack  125000      Data_Scientist            8  Hyderabad
# 6  Rajesh   80000      Data_Scientist           10    Chennai

# %% [markdown]
# ##### 13. sort based on exp in asc

# %%
df.sort_values(by = "No_of_Years")
# Out:
#      Name  Salary         Designation  No_of_Years   Location
# 3   Abdul   75000   Jr_Data_Scientist            5  Hyderabad
# 1    Siva  100000             Manager            7   Banglore
# 5    Jack  125000      Data_Scientist            8  Hyderabad
# 6  Rajesh   80000      Data_Scientist           10    Chennai
# 0     Ram  200000             Manager           12    Chennai
# d    John  250000      Data_Scientist           15   Cheannai

# %% [markdown]
# ##### 14. sort by designation and based on exp in asc

# %%
df.sort_values(by = ["Designation", "No_of_Years"] , ascending = [True, False])
# Out:
#      Name  Salary         Designation  No_of_Years   Location
# 3   Abdul   75000   Jr_Data_Scientist            5  Hyderabad
# d    John  250000      Data_Scientist           15   Cheannai
# 6  Rajesh   80000      Data_Scientist           10    Chennai
# 5    Jack  125000      Data_Scientist            8  Hyderabad
# 0     Ram  200000             Manager           12    Chennai
# 1    Siva  100000             Manager            7   Banglore

# %%
df.sort_values(by = ["Designation", "Salary"] , ascending = [True, False])
# Out:
#      Name  Salary         Designation  No_of_Years   Location
# 3   Abdul   75000   Jr_Data_Scientist            5  Hyderabad
# d    John  250000      Data_Scientist           15   Cheannai
# 5    Jack  125000      Data_Scientist            8  Hyderabad
# 6  Rajesh   80000      Data_Scientist           10    Chennai
# 0     Ram  200000             Manager           12    Chennai
# 1    Siva  100000             Manager            7   Banglore
